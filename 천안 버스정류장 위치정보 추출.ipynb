# %%
import pandas as pd

# %%
df = pd.read_csv("전국버스정류장 위치정보.csv", encoding = 'CP949')
df
# Out:
#               정류장아이디      정류장 명칭  정류장 유형 중앙차로 여부                노드영문명  \
# 0       TSB254000096        양지연립     1.0       N        Yangjiyeollip
# 1       TSB254000097         구문소     1.0       N              Gumunso
# 2       TSB254000098         구문소     1.0       N              Gumunso
# 3       TSB254000099      사시랭이마을     1.0       N      Sasiraengimaeul
# 4       TSB254000100      자연사박물관     1.0       N  Jayeonsabangmulgwan
# ...              ...         ...     ...     ...                  ...
# 187640  GGB277103271  성남IC출입(경유)     0.0       N                  NaN
# 187641  GGB277103272    성남TG(경유)     0.0       N                  NaN
# 187642  GGB277103273    성남TG(경유)     0.0       N                  NaN
# 187643  GGB277103274    하남JC(경유)     0.0       N                  NaN
# 187644  GGB277103275    하남JC(경유)     0.0       N                  NaN
#
#                위도          경도             수집일시      단축아이디   도시코드  도시명
# ...

# %%
df1 = df.query("도시명 == '천안시'")
df1.head(50)
# Out:
#              정류장아이디       정류장 명칭  정류장 유형 중앙차로 여부  \
# 48132  CAB214000026         삼성생명     1.0       N
# 48133  CAB214000027          경찰서     1.0       N
# 48134  CAB214000030          평택역     1.0       N
# 48135  CAB214000033  신평11통(유천3리)     1.0       N
# 48136  CAB214001064   신평9통(유천1리)     1.0       N
# 48137  CAB214001065         유천2리     1.0       N
# 48138  CAB214001664  신평11동(유천3리)     1.0       N
# 48139  CAB214010093         안성천교     1.0       N
# 48140  CAB214010094     노와4리(1반)     1.0       N
# 48141  CAB214015653      추팔리(종점)     1.0       N
# 48142  CAB214015659         노와4리     1.0       N
# 48143  CAB214015664    노와4리,대사2리     1.0       N
# 48144  CAB214015722      평택버스터미널     1.0       N
# 48145  CAB214015723     평택버스터미널앞     1.0       N
# 48146  CAB214015730         박애병원     1.0       N
# 48147  CAB214015731     평택경찰서사거리     1.0       N
# 48148  CAB214015754      성동초등학교앞     1.0       N
# 48149  CAB214015760         노와2리     1.0       N
# ...

# %%
df1.shape
# Out:
# (2362, 11)

# %%
df1.to_clipboard(index=False)
